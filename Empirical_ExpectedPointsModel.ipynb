# %% [markdown]
# # Empirical Expected Points Model

# %% [markdown]
# **Authors:**
# Iain Muir, iam9ez
# Hriday Singh,
# Connor Smith,

# %% [markdown]
# *Date: September 9th, 2021*

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ### 0.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import statistics

# %% [markdown]
# ### 1.0 Load Data

# %%
PATH = '/Users/iainmuir/Desktop/4Y 1S/STAT 4800/Dataset/2019 PFF All Plays.csv'
DATA = pd.read_csv(PATH)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
DATA.shape
# Out:
# (167027, 177)

# %%
DATA.head()
# Out:
#    pff_PLAYID  pff_GAMEID pff_GAMEDATE  pff_GAMESEASON pff_WEEK  \
# 0     3401248       16800      1/13/20            2019       FC
# 1     3401250       16800      1/13/20            2019       FC
# 2     3401251       16800      1/13/20            2019       FC
# 3     3401252       16800      1/13/20            2019       FC
# 4     3401253       16800      1/13/20            2019       FC
#
#    pff_GSISGAMEKEY  pff_GSISPLAYID  pff_QUARTER  pff_DOWN pff_CLOCK  ...  \
# 0            76953               0            1         0     15:00  ...
# 1            76953               0            1         1     15:00  ...
# 2            76953               0            1         2     14:35  ...
# 3            76953               0            1         1     14:19  ...
# 4            76953               0            1         1     13:58  ...
#
#    pff_STSAFETIES  pff_TACKLE  pff_TACKLEASSIST  pff_TEALIGNMENT  \
# 0             NaN         NaN               NaN              NaN
# 1             NaN    LAST D18               NaN                R
# 2             NaN    LAST D01               NaN              NaN
# 3             NaN    LAST D06               NaN                R
# 4             NaN    LAST D05               NaN                R
#
#    pff_TOUCHDOWN  pff_UNBLOCKEDPRESSURE  pff_VISE           pff_WRALIGNMENT  \
# 0            NaN                    NaN       NaN                       NaN
# 1            NaN                    NaN       NaN        LWR; SLoWR^; SLiWR
# 2            NaN                    NaN       NaN  LWR^; SRiWR; SRoWR; RWR^
# 3            NaN                    NaN       NaN          LWR^; SRWR; RWR^
# 4            NaN                    NaN       NaN        SRiWR; SRoWR^; RWR
#
#    pff_PLAYCLOCK  pff_RUNPASSOPTION
# 0            NaN                  0
# 1            3.0                  0
# 2           23.0                  0
# 3           17.0                  0
# 4           25.0                  1
#
# [5 rows x 177 columns]

# %%
DATA.describe()
# Out:
#          pff_PLAYID     pff_GAMEID  pff_GAMESEASON  pff_GSISGAMEKEY  \
# count  1.670270e+05  167027.000000        167027.0    167027.000000
# mean   3.187349e+06   15459.272088          2019.0     74972.614553
# std    1.211107e+05     462.439957             0.0      1267.438124
# min    2.982310e+06   14901.000000          2019.0     73049.000000
# 25%    3.083844e+06   15135.000000          2019.0     73810.000000
# 50%    3.186109e+06   15368.000000          2019.0     74990.000000
# 75%    3.286893e+06   15605.000000          2019.0     76239.000000
# max    3.402800e+06   16800.000000          2019.0     76953.000000
#
#        pff_GSISPLAYID    pff_QUARTER       pff_DOWN   pff_BLITZDOG  \
# count   167027.000000  167027.000000  167027.000000  167027.000000
# mean      2011.392799       2.488831       1.789022       0.125944
# std       1182.639051       1.114170       1.131771       0.331787
# min          0.000000       1.000000       0.000000       0.000000
# 25%        994.000000       2.000000       1.000000       0.000000
# 50%       1995.000000       2.000000       2.000000       0.000000
# 75%       2991.000000       3.000000       3.000000       0.000000
# max       5246.000000       5.000000       4.000000       1.000000
#
#        pff_CATCHABLE   pff_DEEPPASS  ...  pff_PASSDEPTH  pff_PASSWIDTH  \
# count   70988.000000  167027.000000  ...   67106.000000   58114.000000
# mean        0.560081       0.058320  ...       8.061038      27.194910
# std         0.496381       0.234348  ...      11.000766      16.630412
# min         0.000000       0.000000  ...     -21.000000       0.000000
# 25%         0.000000       0.000000  ...       0.000000      12.000000
# 50%         1.000000       0.000000  ...       5.000000      28.000000
# 75%         1.000000       0.000000  ...      13.000000      43.000000
# max         1.000000       1.000000  ...      59.000000      53.000000
#
#        pff_PLAYENDFIELDPOSITION   pff_PUMPFAKE  pff_QBMOVEDOFFSPOT  \
# count             167027.000000  167027.000000        70988.000000
# mean                   1.464524       0.015578            0.205316
# std                   30.528227       0.123838            0.403935
# min                  -49.000000       0.000000            0.000000
# 25%                  -29.000000       0.000000            0.000000
# 50%                    4.000000       0.000000            0.000000
# 75%                   27.000000       0.000000            0.000000
# max                   50.000000       1.000000            1.000000
#
#         pff_QBRESET  pff_RUNCONCEPT3  pff_SCOREDIFFERENTIAL  pff_PLAYCLOCK  \
# count  70988.000000              0.0          167027.000000  137584.000000
# mean       0.017989              NaN              -1.210014      12.988996
# std        0.132912              NaN              16.022196       7.199358
# min        0.000000              NaN             -79.000000       0.000000
# 25%        0.000000              NaN             -10.000000       8.000000
# 50%        0.000000              NaN               0.000000      12.000000
# 75%        0.000000              NaN               7.000000      18.000000
# max        1.000000              NaN              79.000000      40.000000
#
#        pff_RUNPASSOPTION
# count      167027.000000
# mean            0.174451
# std             0.379498
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
#
# [8 rows x 60 columns]

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167027 entries, 0 to 167026
# Columns: 177 entries, pff_PLAYID to pff_RUNPASSOPTION
# dtypes: float64(29), int64(31), object(117)
# memory usage: 225.6+ MB

# %%
d = DATA.copy()

# %% [markdown]
# ### 2.0 Transform Data

# %% [markdown]
# #### 2.1 Remove Garbage Time

# %%
d = d.loc[d['pff_GARBAGETIME'] == 0]

# %%
d = d.loc[(d['pff_QUARTER'] == 1) | (d['pff_QUARTER'] == 3)]

# %%
d = d.reset_index(drop=True)

# %%
d.shape
# Out:
# (79912, 177)

# %% [markdown]
# #### 2.2 Split Score to Home/Away

# %%
def split_score(row):
    """
    
    """
    score = row['pff_SCORE']
    h, a = score.split('.')
    h = float('.' + h) * (10 * (10 if len(h) == 2 else 1))
    a = float('.' + a) * (10 * (10 if len(a) == 2 else 1))
    
    return int(h), int(a)

# %%
# %%time

d['pff_SCORE'] = d['pff_SCORE'].astype(str)
s = pd.DataFrame(d['pff_SCORE'])
scores = s.apply(
    lambda r: split_score(r),
    axis=1,
    result_type='expand'
)

# %%
scores.columns = ['homeScore', 'awayScore']

# %%
d['homeScore'], d['awayScore'] = scores['homeScore'], scores['awayScore']

# %% [markdown]
# #### 2.3 Cast Datetime Variables

# %%
d['pff_GAMEDATE'] = pd.to_datetime(d['pff_GAMEDATE'])

# %%
d['pff_CLOCK'] = pd.to_datetime(d['pff_CLOCK']).dt.time

# %% [markdown]
# #### 2.4 Group Point Periods

# %%
def group_point_periods(row):
    """
    
    """
    global drive, last_id, increment
    
    id_, order, type_ = row['pff_GAMEID'], row['pff_SORTORDER'], row['pff_SPECIALTEAMSTYPE']

    if increment:
        drive += 1
        increment = False
        
    if id_ != last_id:
        drive = 1
    last_id = id_

    increment = True if type_ == 'KICKOFF' and order != 1 else False
        
    return drive

# %%
drive = 1
last_id = None
increment = False

# %%
# %%time

games = pd.DataFrame(
    d[['pff_GAMEID', 'pff_SORTORDER', 'pff_SPECIALTEAMSTYPE']]
)
d['pointPeriod'] = games.apply(
    lambda r: group_point_periods(r),
    axis=1
)
# Out:
# CPU times: user 4.34 s, sys: 25.6 ms, total: 4.37 s
# Wall time: 4.49 s

# %%
def assign_points():
    pass

# %%
periods = d.groupby(
    ['pff_GAMEID', 'pointPeriod']
)

# %%
d.loc[(d['pff_GAMEID'] == 16556) & (d['pointPeriod'] == 1)]
# Out:
#      pff_PLAYID  pff_GAMEID pff_GAMEDATE  pff_GAMESEASON pff_WEEK  \
# 466     3368447       16556   2019-12-21            2019       BG
# 467     3368449       16556   2019-12-21            2019       BG
# 468     3368452       16556   2019-12-21            2019       BG
# 469     3368454       16556   2019-12-21            2019       BG
# 470     3368459       16556   2019-12-21            2019       BG
# 471     3368465       16556   2019-12-21            2019       BG
# 472     3368466       16556   2019-12-21            2019       BG
# 473     3368471       16556   2019-12-21            2019       BG
# 474     3368473       16556   2019-12-21            2019       BG
# 475     3368476       16556   2019-12-21            2019       BG
#
#      pff_GSISGAMEKEY  pff_GSISPLAYID  pff_QUARTER  pff_DOWN pff_CLOCK  ...  \
# 466            76924              35            1         0  15:00:00  ...
# 467            76924              49            1         1  15:00:00  ...
# 468            76924              71            1         2  14:56:00  ...
# 469            76924              95            1         3  14:22:00  ...
# 470            76924             116            1         1  14:17:00  ...
# 471            76924             138            1         2  13:44:00  ...
# 472            76924             160            1         3  13:13:00  ...
# 473            76924             184            1         1  12:43:00  ...
# 474            76924             204            1         0  12:34:00  ...
# 475            76924             220            1         0  12:34:00  ...
#
#      pff_TOUCHDOWN  pff_UNBLOCKEDPRESSURE  pff_VISE  \
# 466            NaN                    NaN       NaN
# 467            NaN                    NaN       NaN
# 468            NaN                    NaN       NaN
# 469            NaN                    NaN       NaN
# 470            NaN                    NaN       NaN
# 471            NaN                    NaN       NaN
# 472            NaN                    NaN       NaN
# 473        CASS 45                    NaN       NaN
# 474            NaN                    NaN       NaN
# 475            NaN                    NaN       NaN
#
#                           pff_WRALIGNMENT  pff_PLAYCLOCK  pff_RUNPASSOPTION  \
# 466                                   NaN           13.0                  0
# 467   LWR^(-18.5); SRWR(+9.5); RWR(+17.5)            NaN                  0
# 468  LWR^(-16.5); SRWR(+8.5); RWR^(+18.5)           19.0                  1
# 469  LWR(-16.5); SLWR^(-7.5); RWR^(+19.5)           13.0                  0
# 470               SRWR(+9.5); RWR^(+12.5)           13.0                  0
# 471               LWR(-13.5); RWR^(+13.5)           16.0                  0
# 472                           LWR^(-19.5)           16.0                  0
# 473               LWR^(-18.5); RWR(+13.5)           13.0                  0
# 474                                   NaN           12.0                  0
# 475                                   NaN           12.0                  0
#
#      homeScore  awayScore  pointPeriod  periodScore
# 466          0          0            1          7.0
# 467          0          0            1          7.0
# 468          0          0            1          7.0
# 469          0          0            1          7.0
# 470          0          0            1          7.0
# 471          0          0            1          7.0
# 472          0          0            1         10.0
# 473          0          0            1         10.0
# 474          0          6            1         10.0
# 475          0          7            1         10.0
#
# [10 rows x 181 columns]

# %%
# %%time

point_periods = list()
for name, group in periods:
    g = group.reset_index()
    num = len(g)
    
#     try:
    home = g['homeScore'].iloc[-1] - g['homeScore'].iloc[0]
    away = g['awayScore'].iloc[-1] - g['awayScore'].iloc[0]
#     except IndexError:
#         point_periods.extend([None]*num)
#         continue
    
    diff = home - away
    if diff == 0:
        print(len(g))
    points = np.ones(num) * diff
    
    point_periods.extend(points)
# Out:
# 2
# 1
# 7
# 10
# 12
# 4
# 1
# 10
# 19
# 32
# 15
# 12
# 19
# 12
# 10
# 9
# 10
# 19
# 20
# 32
# 32
# 6
# 3
# 1
# 1
# 24
# 4
# 12
# 19
# 15
# 3
# 1
# 12
# 3
# 22
# 18
# 21
# 7
# 9
# 16
# 13
# 1
# 27
# 11
# 5
# 3
# 14
# 11
# 11
# 12
# 15
# 9
# 5
# 4
# 10
# 6
# 43
# 26
# 9
# 18
# 30
# 4
# 9
# 2
# 3
# 17
# 2
# 9
# 26
# 18
# 4
# 9
# 19
# 10
# 4
# 8
# 5
# 4
# 15
# 8
# 18
# 21
# 1
# 5
# 37
# 36
# 8
# 2
# 6
# 19
# 8
# 29
# 11
# 11
# 17
# 18
# 29
# 1
# 8
# 15
# 2
# 1
# 10
# 3
# 22
# 20
# 6
# 32
# 4
# 8
# 30
# 19
# 10
# 4
# 24
# 2
# 32
# 3
# 2
# 21
# 1
# 5
# 4
# 9
# 12
# 1
# 3
# 3
# 2
# 9
# 9
# 1
# 6
# 24
# 18
# 2
# 1
# 14
# 4
# 3
# 2
# 5
# 9
# 29
# 19
# 20
# 8
# 11
# 6
# 5
# 5
# 22
# 7
# 11
# 11
# 11
# 27
# 11
# 8
# 6
# 9
# 2
# 2
# 1
# 2
# 20
# 1
# 14
# 3
# 6
# 14
# 23
# 4
# 7
# 13
# 17
# 1
# 42
# 2
# 22
# 6
# 12
# 34
# 1
# 4
# 4
# 8
# 14
# 4
# 32
# 24
# 5
# 25
# 39
# 28
# 12
# 4
# 5
# 25
# 3
# 6
# 5
# 34
# 4
# 1
# 22
# 16
# 16
# 49
# 2
# 1
# 2
# 5
# 16
# 19
# 1
# 10
# 14
# 14
# 5
# 4
# 9
# 6
# 2
# 5
# 6
# 7
# 2
# 11
# 14
# 1
# 36
# 1
# 8
# 3
# 1
# 20
# 13
# 6
# 3
# 6
# 3
# 11
# 2
# 25
# 2
# 31
# 4
# 6
# 47
# 11
# 23
# 1
# 10
# 24
# 11
# 17
# 32
# 3
# 2
# 8
# 1
# 8
# 17
# 18
# 14
# 8
# 1
# 10
# 1
# 23
# 11
# 3
# 29
# 48
# 35
# 476       3368482       16556   2019-12-21            2019       BG
# ...           ...         ...          ...             ...      ...
# 79859     2984603       14902   2019-08-24            2019        0
# 79860     2984607       14902   2019-08-24            2019        0
# 79861     2984612       14902   2019-08-24            2019        0
# 79862     2984617       14902   2019-08-24            2019        0
# 79863     2984625       14902   2019-08-24            2019        0
#
#        pff_GSISGAMEKEY  pff_GSISPLAYID  pff_QUARTER  pff_DOWN pff_CLOCK  ...  \
# 472              76924             160            1         3  13:13:00  ...
# 473              76924             184            1         1  12:43:00  ...
# 474              76924             204            1         0  12:34:00  ...
# 475              76924             220            1         0  12:34:00  ...
# 476              76924             234            1         1  12:34:00  ...
# ...                ...             ...          ...       ...       ...  ...
# 79859            73051            2225            3         2  13:31:00  ...
# 79860            73051            2247            3         3  13:01:00  ...
# 79861            73051            2269            3         4  12:50:00  ...
# 79862            73051            2292            3         4  12:49:00  ...
# 79863            73051            2311            3         1  12:44:00  ...
#
#        pff_TOUCHDOWN  pff_UNBLOCKEDPRESSURE                      pff_VISE  \
# 472              NaN                    NaN                           NaN
# 473          CASS 45                    NaN                           NaN
# 474              NaN                    NaN                           NaN
# 475              NaN                    NaN                           NaN
# 476              NaN                    NaN                           NaN
# ...              ...                    ...                           ...
# 79859            NaN                    NaN                           NaN
# 79860            NaN                    NaN                           NaN
# 79861            NaN                    NaN                           NaN
# 79862            NaN                    NaN  HIUN D04 (VL); HIUN D23 (VR)
# 79863            NaN                    NaN                           NaN
#
#                                          pff_WRALIGNMENT  pff_PLAYCLOCK  \
# 472                                          LWR^(-19.5)           16.0
# 473                              LWR^(-18.5); RWR(+13.5)           13.0
# 474                                                  NaN           12.0
# 475                                                  NaN           12.0
# 476                LWR(-11.5); SLoWR(-4.5); SLiWR^(-2.5)           11.0
# ...                                                  ...            ...
# 79859  LWR^(-19.5); SRiWR^(+5.5); SRoWR(+10.5); RWR(+...           24.0
# 79860  LWR^(-16.5); SRiWR^(+4.5); SRoWR(+8.5); RWR(+1...           15.0
# 79861                                                NaN           12.0
# 79862                                                NaN           21.0
# 79863  LWR^(-19.5); SLoWR(-12.5); SLiWR(-6.5); RWR^(+...           16.0
#
#        pff_RUNPASSOPTION  homeScore  awayScore  pointPeriod  periodScore
# 472                    0          0          0            1         10.0
# 473                    0          0          0            1         10.0
# 474                    0          0          6            1         10.0
# 475                    0          0          7            1         10.0
# 476                    0          0          7            2         10.0
# ...                  ...        ...        ...          ...          ...
# 79859                  1         28         21            4         11.0
# 79860                  0         28         21            4         11.0
# 79861                  0         28         21            4         11.0
# 79862                  0         28         21            4         11.0
# 79863                  1         28         21            4         11.0
#
# [5219 rows x 181 columns]

# %% [markdown]
# ### 3.0 Expected Points Model

# %%
points = list()
MAX = max(d['pff_DISTANCE'])
SEED = 42

YTG_DEV = {
    'long': 4,
    'medium': 3,
    'short': 2,
    'inches': 1
}
YTG_MIN = {
    'long': 10,
    'medium': 6,
    'short': 3,
    'inches': 1
}
POSITION_DEV = 5 # yards

# %%
def EP(down, ytg, position, own):
    """
    
    """
    dist_ = 'long' if ytg in range(10, MAX) else \
            'medium' if ytg in range(6, 10) else \
            'short' if ytg in range(3, 6) else \
            'inches'
    ytg_dev = YTG_DEV[dist_]
    ytg_min = YTG_MIN[dist_]
    
    position *= -1 if own else 1
    fp_right = position - POSITION_DEV
    fp_left = position + POSITION_DEV
    
    # Off the field left
    if fp_left > 0 and fp_right < 0:
        fp_left = -1
    # Redzone -- shrink deviation to 3 yards
    elif 0 < position < 20:
        fp_right += 2
        fp_left -= 2
    
    samples = d.loc[
        (d['pff_DOWN'] == down) &
        (d['pff_DISTANCE'] >= max(ytg_min, ytg - ytg_dev)) &
        (d['pff_DISTANCE'] <= ytg + ytg_dev) &
        (d['pff_FIELDPOSITION'] >= fp_right) &
        (d['pff_FIELDPOSITION'] <= fp_left)
    ]

    sample_ep = samples['periodScore'].mean()
    
    return round(sample_ep, 2)

# %%
STATE = {
    'down': 1,
    'ytg': 10,
    'position': 2,
    'own': False
}

# %%
ep = EP(**STATE)

# %%
print('''
    Expected Points Model:
    S (Down: {}, YTG: {}, Position: {}) == {} EP
'''.format(
    STATE['down'],
    STATE['ytg'],
    ('Own ' if STATE['own'] else '') + str(STATE['position']),
    ep
))
# Out:
#     Expected Points Model:
#     S (Down: 1, YTG: 10, Position: 2) == 0.29 EP

# %% [markdown]
# ### 4.0 Expected Points Added Model

# %%
def EPA(down, ytg, position, own):
    """
    
    """
    global points
    
    ytg_dev = 4 if ytg in range(10, MAX) else
              3 if ytg in range(6, 10) else
              2 if ytg in range(3, 6) else
              1
                
    SIMULATIONS = 1000
    for i in range(SIMULATIONS):
        point = run_play(down, ytg, position, own)
        points.append(point)
    
    return statistics.mean(points)

# %%
def run_play(down, ytg, position, own):
    dist_ = 'long' if ytg in range(10, MAX) else
            'medium' if ytg in range(6, 10) else
            'short' if ytg in range(3, 6) else
            'inches'
    ytg_dev = YTG_DEV[dist_]
    ytg_min = YTG_MIN[dist_]
    
    position *= -1 if own else 1
    fp_right = position - POSITION_DEV
    fp_left = position + POSITION_DEV
    
    # Off the field left
    if fp_left > 0 and fp_right < 0:
        fp_left = -1
    # Redzone -- shrink deviation to 3 yards
    elif 0 < position < 20:
        fp_right += 2
        fp_left -= 2
    
    samples = d.loc[
        (d['pff_DOWN'] == down) &
        (d['pff_DISTANCE'] >= max(ytg_min, ytg - ytg_dev)) &
        (d['pff_DISTANCE'] <= ytg + ytg_dev) &
        (d['pff_FIELDPOSITION'] >= fp_right) &
        (d['pff_FIELDPOSITION'] <= fp_left)
    ]
    if len(samples) == 0:
        return None
    else:
        sample = samples.sample(n=1, random_state=SEED)
        
        # Define conditions for a TD, FG
        if True:
            score = True
            scored = 6
            
            xps = d.loc[
                (d['pff_DOWN'] == 0) &
                (d['pff_DISTANCE'] == 0) &
                (d['pff_FIELDPOSITION'] == 0)
            ]
            xp = xps.sample(n=1, random_state=SEED)
            result = xp['pff_KICKRESULT']
            scored += 1 if 'MADE' in result else 0
        elif True:
            score = True
            scored = 3
        else:
            score = False
    
    if score:
        return scored
    else:
        return run_play(d, y, p)
